# %%
""" source: https://code.visualstudio.com/docs/datascience/data-science-tutorial#_prepare-the-data """

import pandas as pd
import numpy as np

data = pd.read_csv('titanic.csv')

# %%
""" curate data """
data.replace('?', np.nan, inplace=True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)
""" relations between variables and survives """
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
""" reasing data and included the last variable """
data = data[['sex', 'pclass', 'age', 'relatives', 'fare', 'survived']].dropna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/elvirodominguezsoriano/Library/Mobile Documents/com~apple~CloudDocs/GitHub/codes/python/notebooks/titanic.ipynb Celda 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/elvirodominguezsoriano/Library/Mobile%20Documents/com~apple~CloudDocs/GitHub/codes/python/notebooks/titanic.ipynb#ch0000005?line=0'>1</a> """ reasing data and included the last variable """
# ----> <a href='vscode-notebook-cell:/Users/elvirodominguezsoriano/Library/Mobile%20Documents/com~apple~CloudDocs/GitHub/codes/python/notebooks/titanic.ipynb#ch0000005?line=1'>2</a> data = data[['sex', 'pclass', 'age', 'relatives', 'fare', 'survived']].dropna()
#       <a href='vscode-notebook-cell:/Users/elvirodominguezsoriano/Library/Mobile%20Documents/com~apple~CloudDocs/GitHub/codes/python/notebooks/titanic.ipynb#ch0000005?line=2'>3</a> print(data)
#
# TypeError: 'method' object is not subscriptable
